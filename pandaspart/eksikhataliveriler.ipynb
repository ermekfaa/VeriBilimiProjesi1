# %% [markdown]
# # Hatalı ve Eksik Veriler

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("starwars.xlsx")

# %% [markdown]
# ## Bundan Önce

# %% [markdown]
# C ve C++ gibi dillerde Null
#
# Python NaN veya None

# %%
np.NaN
# Out:
# nan

# %%
42 == 42
# Out:
# True

# %%
np.NaN == np.NaN
# Out:
# False

# %%
np.NaN is np.NaN
# Out:
# True

# %% [markdown]
# ## Veri Kontrol

# %%
df
# Out:
#                 name  height   mass hair_color   skin_color eye_color  \
# 0     Luke Skywalker   172.0   77.0      blond         fair      blue
# 1              C-3PO   167.0    NaN        NaN         gold    yellow
# 2                NaN     NaN    NaN        NaN          NaN       NaN
# 3              R2-D2    96.0   32.0        NaN  white, blue       red
# 4        Darth Vader   202.0  136.0       none        white    yellow
# 5        Leia Organa     NaN   49.0      brown          NaN       NaN
# 6     Obi-Wan Kenobi   182.0   84.0     auburn         fair      grey
# 7   Anakin Skywalker   188.0   84.0      blond         fair      blue
# 8          Chewbacca   228.0    NaN      brown          NaN       NaN
# 9               Yoda    66.0   17.0       grey         pale    yellow
# 10               NaN     NaN    NaN        NaN          NaN       NaN
# 11         Palpatine   170.0   75.0        NaN          NaN       NaN
# ...

# %%
df.isnull()
# Out:
#      name  height   mass  hair_color  skin_color  eye_color  birth_year  \
# 0   False   False  False       False       False      False       False
# 1   False   False   True        True       False      False       False
# 2    True    True   True        True        True       True        True
# 3   False   False  False        True       False      False       False
# 4   False   False  False       False       False      False       False
# 5   False    True  False       False        True       True       False
# 6   False   False  False       False       False      False       False
# 7   False   False  False       False       False      False       False
# 8   False   False   True       False        True       True       False
# 9   False   False  False       False       False      False       False
# 10   True    True   True        True        True       True        True
# 11  False   False  False        True        True       True        True
# ...

# %%
df.isna()
# Out:
#      name  height   mass  hair_color  skin_color  eye_color  birth_year  \
# 0   False   False  False       False       False      False       False
# 1   False   False   True        True       False      False       False
# 2    True    True   True        True        True       True        True
# 3   False   False  False        True       False      False       False
# 4   False   False  False       False       False      False       False
# 5   False    True  False       False        True       True       False
# 6   False   False  False       False       False      False       False
# 7   False   False  False       False       False      False       False
# 8   False   False   True       False        True       True       False
# 9   False   False  False       False       False      False       False
# 10   True    True   True        True        True       True        True
# 11  False   False  False        True        True       True        True
# ...

# %%
df.notnull()
# Out:
#      name  height   mass  hair_color  skin_color  eye_color  birth_year  \
# 0    True    True   True        True        True       True        True
# 1    True    True  False       False        True       True        True
# 2   False   False  False       False       False      False       False
# 3    True    True   True       False        True       True        True
# 4    True    True   True        True        True       True        True
# 5    True   False   True        True       False      False        True
# 6    True    True   True        True        True       True        True
# 7    True    True   True        True        True       True        True
# 8    True    True  False        True       False      False        True
# 9    True    True   True        True        True       True        True
# 10  False   False  False       False       False      False       False
# 11   True    True   True       False       False      False       False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        21 non-null     object
#  1   height      14 non-null     float64
#  2   mass        13 non-null     float64
#  3   hair_color  14 non-null     object
#  4   skin_color  13 non-null     object
#  5   eye_color   12 non-null     object
#  6   birth_year  13 non-null     float64
#  7   sex         17 non-null     object
#  8   homeworld   12 non-null     object
#  9   species     20 non-null     object
# dtypes: float64(3), object(7)
# memory usage: 1.9+ KB

# %%
len(df)
# Out:
# 23

# %%
df.isnull().sum()
# Out:
# name           2
# height         9
# mass          10
# hair_color     9
# skin_color    10
# eye_color     11
# birth_year    10
# sex            6
# homeworld     11
# species        3
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 81

# %%
df.isna().sum().sum()
# Out:
# 81

# %%
df.columns
# Out:
# Index(['name', 'height', 'mass', 'hair_color', 'skin_color', 'eye_color',
#        'birth_year', 'sex', 'homeworld', 'species'],
#       dtype='object')

# %%
df.shape
# Out:
# (23, 10)

# %%
81 / 230 * 100
# Out:
# 35.21739130434783

# %%
print("Eksik veri oranı: %", round(df.isna().sum().sum() / len(df) * len(df.columns)))
# Out:
# Eksik veri oranı: % 35

# %%
df[df["homeworld"].notnull()]
# Out:
#                 name  height   mass hair_color   skin_color eye_color  \
# 0     Luke Skywalker   172.0   77.0      blond         fair      blue
# 1              C-3PO   167.0    NaN        NaN         gold    yellow
# 3              R2-D2    96.0   32.0        NaN  white, blue       red
# 4        Darth Vader   202.0  136.0       none        white    yellow
# 6     Obi-Wan Kenobi   182.0   84.0     auburn         fair      grey
# 7   Anakin Skywalker   188.0   84.0      blond         fair      blue
# 11         Palpatine   170.0   75.0        NaN          NaN       NaN
# 12         Boba Fett     NaN    NaN        NaN          NaN       NaN
# 13          Han Solo   180.0   80.0      brown          NaN     brown
# 15        Darth Maul     NaN    NaN       none          red    yellow
# 17          Grievous   216.0  159.0       none          NaN       NaN
# 22     Padmé Amidala   165.0   45.0      brown        light     brown
#
#     birth_year     sex homeworld  species
# ...
